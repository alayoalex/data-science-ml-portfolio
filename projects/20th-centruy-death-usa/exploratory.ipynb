# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Loading Dataset

# %%
data = pd.read_csv('data/20th century deaths in US - CDC.csv')

# %%
data.head()
# Out:
#           Entity  Year  Accidents (excl. road) - Deaths  \
# 0  United States  1900                          14429.0
# 1  United States  1901                          16958.0
# 2  United States  1902                          14915.0
# 3  United States  1903                          17050.0
# 4  United States  1904                          18228.0
#
#    Accidents (total)  - Deaths  Arteriosclerosis  - Deaths  \
# 0                      14429.0                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#    Bronchitis  - Deaths  Cancers  - Deaths  COPD  - Deaths  \
# 0                   NaN              12769             NaN
# 1                8171.0              13438             NaN
# 2                8112.0              13653             NaN
# ...

# %%
data.describe()
# Out:
#               Year  Accidents (excl. road) - Deaths  \
# count    94.000000                        92.000000
# mean   1949.659574                     52405.489130
# std      29.041888                     12725.581504
# min    1900.000000                     14429.000000
# 25%    1926.250000                     47530.250000
# 50%    1949.500000                     55103.000000
# 75%    1974.750000                     60294.250000
# max    1998.000000                     75215.000000
#
#        Accidents (total)  - Deaths  Arteriosclerosis  - Deaths  \
# count                    72.000000                   40.000000
# mean                  96860.486111                30450.000000
# std                   12683.979525                 5113.234994
# min                   14429.000000                18047.000000
# 25%                   92680.750000                28566.500000
# 50%                   95475.500000                31601.500000
# ...

# %%
for col in data.columns:
    print(col)
# Out:
# Entity
# Year
# Accidents (excl. road) - Deaths
# Accidents (total)  - Deaths
# Arteriosclerosis  - Deaths
# Bronchitis  - Deaths
# Cancers  - Deaths
# COPD  - Deaths
# Dementia  - Deaths
# Diabetes  - Deaths
# Diarrheal disease  - Deaths
# Heart disease  - Deaths
# Homicide  - Deaths
# Kidney infection  - Deaths
# Liver disease  - Deaths
# Neonatal disorders  - Deaths
# Nephritis  - Deaths
# Other causes  - Deaths
# Pneumonia and influenza  - Deaths
# Respiratory disease  - Deaths
# Road accidents  - Deaths
# Septicemia  - Deaths
# Stroke  - Deaths
# Suicide  - Deaths
# Syphilis  - Deaths
# Total deaths  - Deaths
# Tuberculosis  - Deaths
# Non-communicable diseases (NCDs)  - Deaths
# Communicable, infectious, neonatal and other deaths  - Deaths
# Accidents (excl. road) - Death Rates
# Accidents (total) - Death Rates
# Arteriosclerosis - Death Rates
# Bronchitis - Death Rates
# Cancers - Death Rates
# COPD - Death Rates
# Dementia - Death Rates
# Diabetes - Death Rates
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of            Entity  Year  Accidents (excl. road) - Deaths  \
# 0   United States  1900                          14429.0
# 1   United States  1901                          16958.0
# 2   United States  1902                          14915.0
# 3   United States  1903                          17050.0
# 4   United States  1904                          18228.0
# ..            ...   ...                              ...
# 89  United States  1994                          48913.0
# 90  United States  1995                          49957.0
# 91  United States  1996                          51299.0
# 92  United States  1997                          52186.0
# 93  United States  1998                          54334.0
#
#     Accidents (total)  - Deaths  Arteriosclerosis  - Deaths  \
# 0                       14429.0                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# ...
